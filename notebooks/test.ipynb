# %%
import sys
import os
from pathlib import Path

# Get project root (parent of "notebooks")
root_dir = Path(os.getcwd()).resolve().parent
sys.path.insert(0, str(root_dir))

from src.dataProcessing import preprocess



df, scaler = preprocess.preprocess_data()
df.head()
# Out:
#         Date    Area Name Road/Intersection Name  Traffic Volume  \
# 0 2022-01-01  Indiranagar          100 Feet Road           50590
# 1 2022-01-01  Indiranagar               CMH Road           30825
# 2 2022-01-01   Whitefield    Marathahalli Bridge            7399
# 3 2022-01-01  Koramangala    Sony World Junction           60874
# 4 2022-01-01  Koramangala          Sarjapur Road           57292
#
#    Average Speed  Travel Time Index  Congestion Level  \
# 0       0.433156           1.500000          1.000000
# 1       0.134360           1.500000          1.000000
# 2       0.493967           1.039069          0.244494
# 3       0.341271           1.500000          1.000000
# 4       0.302572           1.500000          1.000000
#
#    Road Capacity Utilization  Incident Reports  Environmental Impact  \
# 0                 100.000000                 0               151.180
# 1                 100.000000                 1               111.650
# ...

# %%
df.isnull().sum()
# Out:
# Date                                  0
# Area Name                             0
# Road/Intersection Name                0
# Traffic Volume                        0
# Average Speed                         0
# Travel Time Index                     0
# Congestion Level                      0
# Road Capacity Utilization             0
# Incident Reports                      0
# Environmental Impact                  0
# Public Transport Usage                0
# Traffic Signal Compliance             0
# Parking Usage                         0
# Pedestrian and Cyclist Count          0
# Weather Conditions                    0
# Roadwork and Construction Activity    0
# day_of_week                           0
# is_weekend                            0
# month                                 0
# year                                  0
# dtype: int64

# %%
df['Date']
# Out:
# 0      2022-01-01
# 1      2022-01-01
# 2      2022-01-01
# 3      2022-01-01
# 4      2022-01-01
#           ...
# 8931   2024-08-09
# 8932   2024-08-09
# 8933   2024-08-09
# 8934   2024-08-09
# 8935   2024-08-09
# Name: Date, Length: 8936, dtype: datetime64[ns]
