# %%
import sys
import os
from pathlib import Path

# Get project root (parent of "notebooks")
root_dir = Path(os.getcwd()).resolve().parent
sys.path.insert(0, str(root_dir))

from src.dataProcessing import preprocess2
import pandas as pd
import numpy as np


df, scaler = preprocess2.preprocess_data()
df.head()
# Out:
#         Date    Area Name Road/Intersection Name  Traffic Volume  \
# 0 2022-01-01  Indiranagar          100 Feet Road        0.683671
# 1 2022-01-01  Indiranagar               CMH Road        0.392178
# 2 2022-01-01   Whitefield    Marathahalli Bridge        0.046692
# 3 2022-01-01  Koramangala    Sony World Junction        0.835339
# 4 2022-01-01  Koramangala          Sarjapur Road        0.782512
#
#    Average Speed  Travel Time Index  Congestion Level  \
# 0       0.433156           1.000000        100.000000
# 1       0.134360           1.000000        100.000000
# 2       0.493967           0.078067         28.347994
# 3       0.341271           1.000000        100.000000
# 4       0.302572           1.000000        100.000000
#
#    Road Capacity Utilization  Incident Reports  Environmental Impact  \
# 0                   1.000000               0.0              0.683671
# 1                   1.000000               0.1              0.392178
# ...

# %%
print(df.columns)
print(df.head())
print(df["Congestion Level"].describe())
# Out:
# Index(['Date', 'Area Name', 'Road/Intersection Name', 'Traffic Volume',
#        'Average Speed', 'Travel Time Index', 'Congestion Level',
#        'Road Capacity Utilization', 'Incident Reports', 'Environmental Impact',
#        'Public Transport Usage', 'Traffic Signal Compliance', 'Parking Usage',
#        'Pedestrian and Cyclist Count', 'Weather Conditions',
#        'Roadwork and Construction Activity', 'day', 'month', 'hour',
#        'day_of_week'],
#       dtype='object')
#         Date    Area Name Road/Intersection Name  Traffic Volume  \
# 0 2022-01-01  Indiranagar          100 Feet Road        0.683671
# 1 2022-01-01  Indiranagar               CMH Road        0.392178
# 2 2022-01-01   Whitefield    Marathahalli Bridge        0.046692
# 3 2022-01-01  Koramangala    Sony World Junction        0.835339
# 4 2022-01-01  Koramangala          Sarjapur Road        0.782512
#
#    Average Speed  Travel Time Index  Congestion Level  \
# ...

# %%
print(df["Road/Intersection Name"].nunique())
print(df["Road/Intersection Name"].unique()[:10])
# Out:
# 16
# ['100 Feet Road' 'CMH Road' 'Marathahalli Bridge' 'Sony World Junction'
#  'Sarjapur Road' 'Trinity Circle' 'Anil Kumble Circle'
#  'Jayanagar 4th Block' 'South End Circle' 'Hebbal Flyover']

# %%
df.isnull().sum()
# Out:
# Date                                  0
# Area Name                             0
# Road/Intersection Name                0
# Traffic Volume                        0
# Average Speed                         0
# Travel Time Index                     0
# Congestion Level                      0
# Road Capacity Utilization             0
# Incident Reports                      0
# Environmental Impact                  0
# Public Transport Usage                0
# Traffic Signal Compliance             0
# Parking Usage                         0
# Pedestrian and Cyclist Count          0
# Weather Conditions                    0
# Roadwork and Construction Activity    0
# day_of_week                           0
# is_weekend                            0
# month                                 0
# year                                  0
# dtype: int64

# %%
df["Weather Conditions"].unique()
# Out:
# array(['Clear', 'Overcast', 'Fog', 'Rain', 'Windy'], dtype=object)

# %%
df.select_dtypes(include=[np.number]).columns
# Out:
# Index(['Traffic Volume', 'Average Speed', 'Travel Time Index',
#        'Congestion Level', 'Road Capacity Utilization', 'Incident Reports',
#        'Environmental Impact', 'Public Transport Usage',
#        'Traffic Signal Compliance', 'Parking Usage',
#        'Pedestrian and Cyclist Count', 'day_of_week', 'is_weekend', 'month',
#        'year'],
#       dtype='object')

# %%
df['Date']
# Out:
# 0      2022-01-01
# 1      2022-01-01
# 2      2022-01-01
# 3      2022-01-01
# 4      2022-01-01
#           ...
# 8931   2024-08-09
# 8932   2024-08-09
# 8933   2024-08-09
# 8934   2024-08-09
# 8935   2024-08-09
# Name: Date, Length: 8936, dtype: datetime64[ns]

# %%
# !pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from src.modelTraining import predictLstm
# Out:
# C:\Users\draza\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\draza\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# ...

# %%
# Take last 6 congestion levels
last_6 = df["Congestion Level"].values[-6:]
print("Last 6 values:", last_6)

# Run prediction
next_value = predictLstm.predict_next_congestion(last_6)
print("Predicted next congestion level:", next_value)
# Out:
# Last 6 values: [1.         0.32382216 1.         1.         0.71150434 0.40330719]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 6
#       3 print("Last 6 values:", last_6)
#       5 # Run prediction
# ----> 6 next_value = predictLstm.predict_next_congestion(last_6)
#       7 print("Predicted next congestion level:", next_value)
#
# File ~\OneDrive\Desktop\Traffic-Flow-Optimization\src\modelTraining\predictLstm.py:20, in predict_next_congestion(input_sequence)
#      17 model_path = os.path.join(model_dir, "model.h5")
#      18 scaler_path = os.path.join(model_dir, "scaler.pkl")
# ---> 20 model = load_model(model_path)
#      21 scaler = joblib.load(scaler_path)
#      23 # Scale the input sequence using the same scaler
#
# ...
